# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Lenovo\OneDrive\Desktop\Book1.csv")

# %%
df
# Out:
#           day temperature windspeed   event
# 0  01-01-2017        32 F         6    Rain
# 1  01-02-2017      -99999         7   Sunny
# 2  01-03-2017        28 F    -99999    Snow
# 3  01-04-2017      -99999         7       0
# 4  01-05-2017        32 F    -99999    Rain
# 5  01-06-2017          31     2 mph   sunny
# 6  01-06-2017          34     -8888  varsha

# %% [markdown]
# <h2 style="color:green">replace()</h2>

# %%
new_df = df.replace(-99999,0)

# %%
new_df
# Out:
#           day temperature windspeed   event
# 0  01-01-2017        32 F         6    Rain
# 1  01-02-2017      -99999         7   Sunny
# 2  01-03-2017        28 F    -99999    Snow
# 3  01-04-2017      -99999         7       0
# 4  01-05-2017        32 F    -99999    Rain
# 5  01-06-2017          31     2 mph   sunny
# 6  01-06-2017          34     -8888  varsha

# %%
df
# Out:
#           day temperature windspeed   event
# 0  01-01-2017        32 F         6    Rain
# 1  01-02-2017      -99999         7   Sunny
# 2  01-03-2017        28 F    -99999    Snow
# 3  01-04-2017      -99999         7       0
# 4  01-05-2017        32 F    -99999    Rain
# 5  01-06-2017          31     2 mph   sunny
# 6  01-06-2017          34     -8888  varsha

# %%
df
# Out:
#           day temperature windspeed   event
# 0  01-01-2017        32 F         6    Rain
# 1  01-02-2017      -99999         7   Sunny
# 2  01-03-2017        28 F    -99999    Snow
# 3  01-04-2017      -99999         7       0
# 4  01-05-2017        32 F    -99999    Rain
# 5  01-06-2017          31     2 mph   sunny
# 6  01-06-2017          34     -8888  varsha

# %%
new_df = df.replace([-8888,-99999],0)

# %%
new_df
# Out:
#           day temperature windspeed   event
# 0  01-01-2017        32 F         6    Rain
# 1  01-02-2017      -99999         7   Sunny
# 2  01-03-2017        28 F    -99999    Snow
# 3  01-04-2017      -99999         7       0
# 4  01-05-2017        32 F    -99999    Rain
# 5  01-06-2017          31     2 mph   sunny
# 6  01-06-2017          34     -8888  varsha

# %%
new_df = df.replace({'temperature':31,'windspeed':7,'event':'0'},np.NaN)

# %%
new_df
# Out:
#           day temperature windspeed   event
# 0  01-01-2017        32 F         6    Rain
# 1  01-02-2017      -99999         7   Sunny
# 2  01-03-2017        28 F    -99999    Snow
# 3  01-04-2017      -99999         7     NaN
# 4  01-05-2017        32 F    -99999    Rain
# 5  01-06-2017          31     2 mph   sunny
# 6  01-06-2017          34     -8888  varsha

# %%
new_df = df.replace({-99999:0,'varsha':0})

# %%
new_df
# Out:
#           day temperature windspeed  event
# 0  01-01-2017        32 F         6   Rain
# 1  01-02-2017      -99999         7  Sunny
# 2  01-03-2017        28 F    -99999   Snow
# 3  01-04-2017      -99999         7      0
# 4  01-05-2017        32 F    -99999   Rain
# 5  01-06-2017          31     2 mph  sunny
# 6  01-06-2017          34     -8888      0

# %%
new_df
# Out:
#           day temperature windspeed  event
# 0  01-01-2017        32 F         6   Rain
# 1  01-02-2017      -99999         7  Sunny
# 2  01-03-2017        28 F    -99999   Snow
# 3  01-04-2017      -99999         7      0
# 4  01-05-2017        32 F    -99999   Rain
# 5  01-06-2017          31     2 mph  sunny
# 6  01-06-2017          34     -8888      0

# %%
new_df = df.replace('[A-Za-z]'," ",regex=True)

# %%
new_df
# Out:
#           day temperature windspeed   event
# 0  01-01-2017        32           6
# 1  01-02-2017      -99999         7
# 2  01-03-2017        28      -99999
# 3  01-04-2017      -99999         7       0
# 4  01-05-2017        32      -99999
# 5  01-06-2017          31     2
# 6  01-06-2017          34     -8888

# %%
new_df = df.replace({'temperature':'[A-Za-z]','windspeed':'[A-Za-z]'}," ",regex=True)

# %%
new_df
# Out:
#           day temperature windspeed   event
# 0  01-01-2017        32           6    Rain
# 1  01-02-2017      -99999         7   Sunny
# 2  01-03-2017        28      -99999    Snow
# 3  01-04-2017      -99999         7       0
# 4  01-05-2017        32      -99999    Rain
# 5  01-06-2017          31     2       sunny
# 6  01-06-2017          34     -8888  varsha

# %%
df = pd.DataFrame({
    'score': ['exceptional','average', 'good', 'poor', 'average', 'exceptional'],
    'student': ['rob', 'maya', 'parthiv', 'tom', 'julian', 'erica']
})
df
# Out:
#          score  student
# 0  exceptional      rob
# 1      average     maya
# 2         good  parthiv
# 3         poor      tom
# 4      average   julian
# 5  exceptional    erica

# %%
df.replace(['poor','average','good','exceptional'],[1,2,3,4])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6416\2662941392.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(['poor','average','good','exceptional'],[1,2,3,4])
#    score  student
# 0      4      rob
# 1      2     maya
# 2      3  parthiv
# 3      1      tom
# 4      2   julian
# 5      4    erica

# %%
df = pd.read_csv("weather_by_cities.csv")

# %%
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %% [markdown]
# <h2 style="color:green">groupby()</h2>

# %%
g = df.groupby('city')

# %%
g.get_group("mumbai")
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %%
g.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
import matplotlib.pyplot as plt
g['temperature'].max().plot(kind='bar')
plt.show()

# %%
india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})


india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %% [markdown]
# <h2 style="color:green">concat()</h2>

# %%
df = pd.concat([india_weather,us_weather])

# %%
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df = pd.concat([india_weather,us_weather], ignore_index=True)

# %%
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
df = pd.concat([india_weather,us_weather],keys=['india','us'])
df
# Out:
#              city  temperature  humidity
# india 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# us    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
df.loc['us']
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
temperature_df = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
}, index=[0,1,2])
temperature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df = pd.DataFrame({
    "city": ["delhi","mumbai"],
    "windspeed": [7,12]},
    index=[1,0])

# %%
df = pd.concat([temperature_df,windspeed_df],axis=1)

# %%
df
# Out:
#        city  temperature    city  windspeed
# 0    mumbai           32  mumbai       12.0
# 1     delhi           45   delhi        7.0
# 2  banglore           30     NaN        NaN

# %%
s = pd.Series(["humid","rain","snow"],name="event")
pd.concat([temperature_df,s],axis=1)
# Out:
#        city  temperature  event
# 0    mumbai           32  humid
# 1     delhi           45   rain
# 2  banglore           30   snow

# %%
import pandas as pd
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %% [markdown]
# <h2 style="color:green">merge()</h2>

# %%
df3 = pd.merge(df1,df2,on="city")

# %%
df3
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35, 38],
})
df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "humidity": [65,68,71],
})
df2
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        71

# %%
df3 = pd.merge(df1,df2,on="city",how="inner")

# %%
df3
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65

# %%
df3 = pd.merge(df1,df2,on="city",how="outer")

# %%
df3
# Out:
#         city  temperature  humidity
# 0  baltimore         38.0       NaN
# 1    chicago         14.0      65.0
# 2   new york         21.0      68.0
# 3    orlando         35.0       NaN
# 4  san diego          NaN      71.0

# %%
df3 = pd.merge(df1,df2,on="city",how="left")

# %%
df3
# Out:
#         city  temperature  humidity
# 0   new york           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           38       NaN

# %%
df3 = pd.merge(df1,df2,on="city",how="outer",indicator=True)

# %%
df3
# Out:
#         city  temperature  humidity      _merge
# 0  baltimore         38.0       NaN   left_only
# 1    chicago         14.0      65.0        both
# 2   new york         21.0      68.0        both
# 3    orlando         35.0       NaN   left_only
# 4  san diego          NaN      71.0  right_only

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35,38],
    "humidity": [65,68,71, 75]
})
df1
# Out:
#         city  temperature  humidity
# 0   new york           21        65
# 1    chicago           14        68
# 2    orlando           35        71
# 3  baltimore           38        75

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "temperature": [21,14,35],
    "humidity": [65,68,71]
})
df2
# Out:
#         city  temperature  humidity
# 0    chicago           21        65
# 1   new york           14        68
# 2  san diego           35        71

# %%
df3 = pd.merge(df1,df2,on="city",how="outer",suffixes=['_x','_y'])
df3
# Out:
#         city  temperature_x  humidity_x  temperature_y  humidity_y
# 0  baltimore           38.0        75.0            NaN         NaN
# 1    chicago           14.0        68.0           21.0        65.0
# 2   new york           21.0        65.0           14.0        68.0
# 3    orlando           35.0        71.0            NaN         NaN
# 4  san diego            NaN         NaN           35.0        71.0

# %%
df = pd.read_csv(r"C:\Users\Lenovo\Downloads\weather.csv")

# %%
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %% [markdown]
# <h2 style="color:green">melt()</h2>

# %%
df2 = pd.melt(df,id_vars=["day"],var_name="city",value_name="temp")

# %%
df2
# Out:
#           day     city  temp
# 0      Monday  chicago    32
# 1     Tuesday  chicago    30
# 2   Wednesday  chicago    28
# 3    Thursday  chicago    22
# 4      Friday  chicago    30
# 5    Saturday  chicago    20
# 6      Sunday  chicago    25
# 7      Monday  chennai    75
# 8     Tuesday  chennai    77
# 9   Wednesday  chennai    75
# 10   Thursday  chennai    82
# 11     Friday  chennai    83
# 12   Saturday  chennai    81
# 13     Sunday  chennai    77
# 14     Monday   berlin    41
# 15    Tuesday   berlin    43
# 16  Wednesday   berlin    45
# 17   Thursday   berlin    38
# 18     Friday   berlin    30
# 19   Saturday   berlin    45
# 20     Sunday   berlin    47

# %%
df = pd.read_csv("weather (2).csv")

# %%
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %% [markdown]
# <h2 style="color:green">pivot()</h2>

# %%
df.pivot(index="date",columns="city")
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
df.pivot(index="city",columns="date")
# Out:
#          temperature                   humidity
# date        5/1/2017 5/2/2017 5/3/2017 5/1/2017 5/2/2017 5/3/2017
# city
# beijing           80       77       79       26       30       35
# mumbai            75       78       82       80       83       85
# new york          65       66       68       56       58       60

# %%
df.pivot(index="city",columns="date",values="humidity")
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %%
df = pd.read_csv("weather2.csv")

# %%
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %% [markdown]
# <h2 style="color:green">pivot_table()</h2>

# %%
import numpy as np 
df = pd.read_csv("weather2.csv")

df = df.pivot_table(index="date",columns="city",aggfunc='sum',margins=True)

# %%
df
# Out:
#          humidity               temperature
# city       mumbai new york  All      mumbai new york  All
# date
# 5/1/2017      163      110  273         153      126  279
# 5/2/2017      111      122  233         162      142  304
# All           274      232  506         315      268  583

# %%
import pandas as pd
df = pd.read_csv("weather3.csv")

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           61        54
# 2 2017-05-03  new york           70        60
# 3 2017-12-01  new york           30        50
# 4 2017-12-02  new york           28        52
# 5 2017-12-03  new york           25        51

# %%
df.pivot_table(index=pd.Grouper(freq="ME",key="date"),columns="city")
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   27.666667

# %% [markdown]
# <h2 style="color:green">Cleaning small messy data </h2>

# %%
import pandas as pd
import numpy as np

data = {
    'Name': ['Alice', 'bob', '  Charlie  ', 'alice', 'BOB', 'David', 'Eve', 'Frank', None],
    'Age': [25, 30, 35, 25, 30, 999, 28, None, 22],
    'City': ['Mumbai', 'delhi', 'MUMBAI', 'Mumbai', 'Delhi', 'Chennai', None, 'Pune', 'pune'],
    'Salary': [50000, 60000, None, 50000, 60000, 70000, 80000, None, 40000],
    'Joining_Date': ['2021-01-15', '15/02/2021', 'March 3 2021', '2021-01-15', '15/02/2021', '2021-06-01', '2021-07-19', '2021-08-25', None],
    'Department': ['HR', 'IT', 'hr', 'HR', 'it', 'Finance', 'IT', 'Finance', None],
    'Rating': ['good', 'exceptional', 'poor', 'good', 'exceptional', 'average', 'poor', None, 'good'],
    'Experience': [2, 5, 8, 2, 5, -3, 6, 4, 1]
}

df = pd.DataFrame(data)
print(df)
# Out:
#           Name    Age     City   Salary  Joining_Date Department       Rating  \
# 0        Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 1          bob   30.0    delhi  60000.0    15/02/2021         IT  exceptional
# 2    Charlie     35.0   MUMBAI      NaN  March 3 2021         hr         poor
# 3        alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 4          BOB   30.0    Delhi  60000.0    15/02/2021         it  exceptional
# 5        David  999.0  Chennai  70000.0    2021-06-01    Finance      average
# 6          Eve   28.0     None  80000.0    2021-07-19         IT         poor
# 7        Frank    NaN     Pune      NaN    2021-08-25    Finance         None
# 8         None   22.0     pune  40000.0          None       None         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df = df.fillna(0)

# %%
df
# Out:
#           Name    Age     City   Salary  Joining_Date Department       Rating  \
# 0        Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 1          bob   30.0    delhi  60000.0    15/02/2021         IT  exceptional
# 2    Charlie     35.0   MUMBAI      0.0  March 3 2021         hr         poor
# 3        alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 4          BOB   30.0    Delhi  60000.0    15/02/2021         it  exceptional
# 5        David  999.0  Chennai  70000.0    2021-06-01    Finance      average
# 6          Eve   28.0        0  80000.0    2021-07-19         IT         poor
# 7        Frank    0.0     Pune      0.0    2021-08-25    Finance            0
# 8            0   22.0     pune  40000.0             0          0         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df['City'].str.title()
# Out:
# 0     Mumbai
# 1      Delhi
# 2     Mumbai
# 3     Mumbai
# 4      Delhi
# 5    Chennai
# 6        NaN
# 7       Pune
# 8       Pune
# Name: City, dtype: object

# %%
df.City = df.City.str.title()

# %%
df
# Out:
#           Name    Age     City   Salary  Joining_Date Department       Rating  \
# 0        Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 1          bob   30.0    Delhi  60000.0    15/02/2021         IT  exceptional
# 2    Charlie     35.0   Mumbai      0.0  March 3 2021         hr         poor
# 3        alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 4          BOB   30.0    Delhi  60000.0    15/02/2021         it  exceptional
# 5        David  999.0  Chennai  70000.0    2021-06-01    Finance      average
# 6          Eve   28.0      NaN  80000.0    2021-07-19         IT         poor
# 7        Frank    0.0     Pune      0.0    2021-08-25    Finance            0
# 8            0   22.0     Pune  40000.0             0          0         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df.Name = df.Name.str.title()

# %%
df.Name = df.Name.str.lstrip()

# %%
df
# Out:
#         Name    Age     City   Salary  Joining_Date Department       Rating  \
# 0      Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 1        Bob   30.0    Delhi  60000.0    15/02/2021         IT  exceptional
# 2  Charlie     35.0   Mumbai      0.0  March 3 2021         hr         poor
# 3      Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 4        Bob   30.0    Delhi  60000.0    15/02/2021         it  exceptional
# 5      David  999.0  Chennai  70000.0    2021-06-01    Finance      average
# 6        Eve   28.0      NaN  80000.0    2021-07-19         IT         poor
# 7      Frank    0.0     Pune      0.0    2021-08-25    Finance            0
# 8        NaN   22.0     Pune  40000.0             0          0         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df.Department = df.Department.str.lstrip()

# %%
df
# Out:
#         Name    Age     City   Salary  Joining_Date Department       Rating  \
# 0      Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 1        Bob   30.0    Delhi  60000.0    15/02/2021         IT  exceptional
# 2  Charlie     35.0   Mumbai      0.0  March 3 2021         hr         poor
# 3      Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 4        Bob   30.0    Delhi  60000.0    15/02/2021         it  exceptional
# 5      David  999.0  Chennai  70000.0    2021-06-01    Finance      average
# 6        Eve   28.0      NaN  80000.0    2021-07-19         IT         poor
# 7      Frank    0.0     Pune      0.0    2021-08-25    Finance            0
# 8        NaN   22.0     Pune  40000.0             0        NaN         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df.Joining_Date
# Out:
# 0      2021-01-15
# 1      15/02/2021
# 2    March 3 2021
# 3      2021-01-15
# 4      15/02/2021
# 5      2021-06-01
# 6      2021-07-19
# 7      2021-08-25
# 8               0
# Name: Joining_Date, dtype: object

# %%
# Example for date strings like '05SEP2014'
df['Joining_Date'] = pd.to_datetime(df['Joining_Date'], format='%d%b%Y')

# Example for date strings like '15/09/2023' (day first)
df['Joining_Date'] = pd.to_datetime(df['Joining_Date'], dayfirst=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 2
#       1 # Example for date strings like '05SEP2014'
# ----> 2 df['Joining_Date'] = pd.to_datetime(df['Joining_Date'], format='%d%b%Y')
#       4 # Example for date strings like '15/09/2023' (day first)
#       5 df['Joining_Date'] = pd.to_datetime(df['Joining_Date'], dayfirst=True)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %%
df
# Out:
#         Name    Age     City   Salary  Joining_Date Department       Rating  \
# 0      Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 1        Bob   30.0    Delhi  60000.0    15/02/2021         IT  exceptional
# 2  Charlie     35.0   Mumbai      0.0  March 3 2021         hr         poor
# 3      Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 4        Bob   30.0    Delhi  60000.0    15/02/2021         it  exceptional
# 5      David  999.0  Chennai  70000.0    2021-06-01    Finance      average
# 6        Eve   28.0      NaN  80000.0    2021-07-19         IT         poor
# 7      Frank    0.0     Pune      0.0    2021-08-25    Finance            0
# 8        NaN   22.0     Pune  40000.0             0        NaN         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df.Name
# Out:
# 0        Alice
# 1          Bob
# 2    Charlie
# 3        Alice
# 4          Bob
# 5        David
# 6          Eve
# 7        Frank
# 8          NaN
# Name: Name, dtype: object

# %%
print(df['Name'].tolist())
# Out:
# ['Alice', 'Bob', 'Charlie  ', 'Alice', 'Bob', 'David', 'Eve', 'Frank', nan]

# %%
df['Name'] = df['Name'].str.strip()

# %%
df
# Out:
#       Name    Age     City   Salary  Joining_Date Department       Rating  \
# 0    Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 1      Bob   30.0    Delhi  60000.0    15/02/2021         IT  exceptional
# 2  Charlie   35.0   Mumbai      0.0  March 3 2021         hr         poor
# 3    Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 4      Bob   30.0    Delhi  60000.0    15/02/2021         it  exceptional
# 5    David  999.0  Chennai  70000.0    2021-06-01    Finance      average
# 6      Eve   28.0      NaN  80000.0    2021-07-19         IT         poor
# 7    Frank    0.0     Pune      0.0    2021-08-25    Finance            0
# 8      NaN   22.0     Pune  40000.0             0        NaN         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df['Joining_Date']
# Out:
# 0      2021-01-15
# 1      15/02/2021
# 2    March 3 2021
# 3      2021-01-15
# 4      15/02/2021
# 5      2021-06-01
# 6      2021-07-19
# 7      2021-08-25
# 8               0
# Name: Joining_Date, dtype: object

# %%
df['Joining_Date'] = pd.to_datetime(df['Joining_Date'], infer_datetime_format=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6416\1152158423.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['Joining_Date'] = pd.to_datetime(df['Joining_Date'], infer_datetime_format=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 df['Joining_Date'] = pd.to_datetime(df['Joining_Date'], infer_datetime_format=True)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# ...

# %%
df['Joining_Date'] = pd.to_datetime(df['Joining_Date'], infer_datetime_format=True, dayfirst=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6416\3240246540.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['Joining_Date'] = pd.to_datetime(df['Joining_Date'], infer_datetime_format=True, dayfirst=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6416\3240246540.py:1: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df['Joining_Date'] = pd.to_datetime(df['Joining_Date'], infer_datetime_format=True, dayfirst=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 1
# ...

# %%
df['Joining_Date'] = pd.to_datetime(df['Joining_Date'], format='mixed', dayfirst=True)

# %%
df.Joining_Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
type(df.Joining_Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df
# Out:
#       Name    Age     City   Salary Joining_Date Department       Rating  \
# 0    Alice   25.0   Mumbai  50000.0   2021-01-15         HR         good
# 1      Bob   30.0    Delhi  60000.0   2021-02-15         IT  exceptional
# 2  Charlie   35.0   Mumbai      0.0   2021-03-03         hr         poor
# 3    Alice   25.0   Mumbai  50000.0   2021-01-15         HR         good
# 4      Bob   30.0    Delhi  60000.0   2021-02-15         it  exceptional
# 5    David  999.0  Chennai  70000.0   2021-06-01    Finance      average
# 6      Eve   28.0      NaN  80000.0   2021-07-19         IT         poor
# 7    Frank    0.0     Pune      0.0   2021-08-25    Finance            0
# 8      NaN   22.0     Pune  40000.0   1970-01-01        NaN         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df.Department = df.Department.replace({'it':"IT",'hr':"HR"})

# %%
df
# Out:
#       Name    Age     City   Salary Joining_Date Department       Rating  \
# 0    Alice   25.0   Mumbai  50000.0   2021-01-15         HR         good
# 1      Bob   30.0    Delhi  60000.0   2021-02-15         IT  exceptional
# 2  Charlie   35.0   Mumbai      0.0   2021-03-03         HR         poor
# 3    Alice   25.0   Mumbai  50000.0   2021-01-15         HR         good
# 4      Bob   30.0    Delhi  60000.0   2021-02-15         IT  exceptional
# 5    David  999.0  Chennai  70000.0   2021-06-01    Finance      average
# 6      Eve   28.0      NaN  80000.0   2021-07-19         IT         poor
# 7    Frank    0.0     Pune      0.0   2021-08-25    Finance            0
# 8      NaN   22.0     Pune  40000.0   1970-01-01        NaN         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df.Experience = df.Experience.replace(-3,3)

# %%
df.Rating = df.Rating.str.capitalize()

# %%
df
# Out:
#       Name    Age     City   Salary Joining_Date Department       Rating  \
# 0    Alice   25.0   Mumbai  50000.0   2021-01-15         HR         Good
# 1      Bob   30.0    Delhi  60000.0   2021-02-15         IT  Exceptional
# 2  Charlie   35.0   Mumbai      0.0   2021-03-03         HR         Poor
# 3    Alice   25.0   Mumbai  50000.0   2021-01-15         HR         Good
# 4      Bob   30.0    Delhi  60000.0   2021-02-15         IT  Exceptional
# 5    David  999.0  Chennai  70000.0   2021-06-01    Finance      Average
# 6      Eve   28.0      NaN  80000.0   2021-07-19         IT         Poor
# 7    Frank    0.0     Pune      0.0   2021-08-25    Finance          NaN
# 8      NaN   22.0     Pune  40000.0   1970-01-01        NaN         Good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5           3
# 6           6
# 7           4
# 8           1

# %%
import pandas as pd
import numpy as np

data = {
    'Name': ['Alice', 'bob', '  Charlie  ', 'alice', 'BOB', 'David', 'Eve', 'Frank', None],
    'Age': [25, 30, 35, 25, 30, 999, 28, None, 22],
    'City': ['Mumbai', 'delhi', 'MUMBAI', 'Mumbai', 'Delhi', 'Chennai', None, 'Pune', 'pune'],
    'Salary': [50000, 60000, None, 50000, 60000, 70000, 80000, None, 40000],
    'Joining_Date': ['2021-01-15', '15/02/2021', 'March 3 2021', '2021-01-15', '15/02/2021', '2021-06-01', '2021-07-19', '2021-08-25', None],
    'Department': ['HR', 'IT', 'hr', 'HR', 'it', 'Finance', 'IT', 'Finance', None],
    'Rating': ['good', 'exceptional', 'poor', 'good', 'exceptional', 'average', 'poor', None, 'good'],
    'Experience': [2, 5, 8, 2, 5, -3, 6, 4, 1]
}

df = pd.DataFrame(data)
print(df)
# Out:
#           Name    Age     City   Salary  Joining_Date Department       Rating  \
# 0        Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 1          bob   30.0    delhi  60000.0    15/02/2021         IT  exceptional
# 2    Charlie     35.0   MUMBAI      NaN  March 3 2021         hr         poor
# 3        alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 4          BOB   30.0    Delhi  60000.0    15/02/2021         it  exceptional
# 5        David  999.0  Chennai  70000.0    2021-06-01    Finance      average
# 6          Eve   28.0     None  80000.0    2021-07-19         IT         poor
# 7        Frank    NaN     Pune      NaN    2021-08-25    Finance         None
# 8         None   22.0     pune  40000.0          None       None         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df
# Out:
#           Name    Age     City   Salary  Joining_Date Department       Rating  \
# 0        Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 1          bob   30.0    delhi  60000.0    15/02/2021         IT  exceptional
# 2    Charlie     35.0   MUMBAI      NaN  March 3 2021         hr         poor
# 3        alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 4          BOB   30.0    Delhi  60000.0    15/02/2021         it  exceptional
# 5        David  999.0  Chennai  70000.0    2021-06-01    Finance      average
# 6          Eve   28.0     None  80000.0    2021-07-19         IT         poor
# 7        Frank    NaN     Pune      NaN    2021-08-25    Finance         None
# 8         None   22.0     pune  40000.0          None       None         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df.City = df.City.str.title()

# %%
df
# Out:
#           Name    Age     City   Salary  Joining_Date Department       Rating  \
# 0        Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 1          bob   30.0    Delhi  60000.0    15/02/2021         IT  exceptional
# 2    Charlie     35.0   Mumbai      NaN  March 3 2021         hr         poor
# 3        alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 4          BOB   30.0    Delhi  60000.0    15/02/2021         it  exceptional
# 5        David  999.0  Chennai  70000.0    2021-06-01    Finance      average
# 6          Eve   28.0     None  80000.0    2021-07-19         IT         poor
# 7        Frank    NaN     Pune      NaN    2021-08-25    Finance         None
# 8         None   22.0     Pune  40000.0          None       None         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df.fillna(0)
# Out:
#           Name    Age     City   Salary  Joining_Date Department       Rating  \
# 0        Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 1          bob   30.0    Delhi  60000.0    15/02/2021         IT  exceptional
# 2    Charlie     35.0   Mumbai      0.0  March 3 2021         hr         poor
# 3        alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 4          BOB   30.0    Delhi  60000.0    15/02/2021         it  exceptional
# 5        David  999.0  Chennai  70000.0    2021-06-01    Finance      average
# 6          Eve   28.0        0  80000.0    2021-07-19         IT         poor
# 7        Frank    0.0     Pune      0.0    2021-08-25    Finance            0
# 8            0   22.0     Pune  40000.0             0          0         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df.Joining_Date= pd.to_datetime(df.Joining_Date, format="mixed", dayfirst=True)

# %%
df
# Out:
#           Name    Age     City   Salary Joining_Date Department       Rating  \
# 0        Alice   25.0   Mumbai  50000.0   2021-01-15         HR         good
# 1          bob   30.0    Delhi  60000.0   2021-02-15         IT  exceptional
# 2    Charlie     35.0   Mumbai      NaN   2021-03-03         hr         poor
# 3        alice   25.0   Mumbai  50000.0   2021-01-15         HR         good
# 4          BOB   30.0    Delhi  60000.0   2021-02-15         it  exceptional
# 5        David  999.0  Chennai  70000.0   2021-06-01    Finance      average
# 6          Eve   28.0     None  80000.0   2021-07-19         IT         poor
# 7        Frank    NaN     Pune      NaN   2021-08-25    Finance         None
# 8         None   22.0     Pune  40000.0          NaT       None         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df.Name = df.Name.str.title()

# %%
df
# Out:
#           Name    Age     City   Salary Joining_Date Department       Rating  \
# 0        Alice   25.0   Mumbai  50000.0   2021-01-15         HR         good
# 1          Bob   30.0    Delhi  60000.0   2021-02-15         IT  exceptional
# 2    Charlie     35.0   Mumbai      NaN   2021-03-03         hr         poor
# 3        Alice   25.0   Mumbai  50000.0   2021-01-15         HR         good
# 4          Bob   30.0    Delhi  60000.0   2021-02-15         it  exceptional
# 5        David  999.0  Chennai  70000.0   2021-06-01    Finance      average
# 6          Eve   28.0     None  80000.0   2021-07-19         IT         poor
# 7        Frank    NaN     Pune      NaN   2021-08-25    Finance         None
# 8         None   22.0     Pune  40000.0          NaT       None         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df.Department = df.Department.replace({"it":"IT","hr":"HR"})

# %%
df
# Out:
#           Name    Age     City   Salary Joining_Date Department       Rating  \
# 0        Alice   25.0   Mumbai  50000.0   2021-01-15         HR         good
# 1          Bob   30.0    Delhi  60000.0   2021-02-15         IT  exceptional
# 2    Charlie     35.0   Mumbai      NaN   2021-03-03         HR         poor
# 3        Alice   25.0   Mumbai  50000.0   2021-01-15         HR         good
# 4          Bob   30.0    Delhi  60000.0   2021-02-15         IT  exceptional
# 5        David  999.0  Chennai  70000.0   2021-06-01    Finance      average
# 6          Eve   28.0     None  80000.0   2021-07-19         IT         poor
# 7        Frank    NaN     Pune      NaN   2021-08-25    Finance         None
# 8         None   22.0     Pune  40000.0          NaT       None         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#           Name    Age     City   Salary Joining_Date Department       Rating  \
# 0        Alice   25.0   Mumbai  50000.0   2021-01-15         HR         good
# 1          Bob   30.0    Delhi  60000.0   2021-02-15         IT  exceptional
# 2    Charlie     35.0   Mumbai      NaN   2021-03-03         HR         poor
# 5        David  999.0  Chennai  70000.0   2021-06-01    Finance      average
# 6          Eve   28.0     None  80000.0   2021-07-19         IT         poor
# 7        Frank    NaN     Pune      NaN   2021-08-25    Finance         None
# 8         None   22.0     Pune  40000.0          NaT       None         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df.loc[7,"Age"] = 20

# %%
df
# Out:
#           Name    Age     City   Salary Joining_Date Department       Rating  \
# 0        Alice   25.0   Mumbai  50000.0   2021-01-15         HR         good
# 1          Bob   30.0    Delhi  60000.0   2021-02-15         IT  exceptional
# 2    Charlie     35.0   Mumbai      NaN   2021-03-03         HR         poor
# 5        David  999.0  Chennai  70000.0   2021-06-01    Finance      average
# 6          Eve   28.0     None  80000.0   2021-07-19         IT         poor
# 7        Frank   20.0     Pune      NaN   2021-08-25    Finance         None
# 8         None   22.0     Pune  40000.0          NaT       None         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df.replace({df['Age']:999,df.City:None,df.Salary:np.NaN,df.Department:None,df.Experience:-3},{35,"Chennai",25000,'IT',3})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 df.replace({df['Age']:999,df.City:None,df.Salary:np.NaN,df.Department:None,df.Experience:-3},{35,"Chennai",25000,'IT',3})
#
# TypeError: unhashable type: 'Series'

# %%
df.replace({
    'Age':        {999: 35},
    'City':       {None: 'Chennai'},
    'Salary':     {np.NaN: 25000},
    'Department': {None: 'IT'},
    'Rating':     {None:'average'},
    'Experience': {-3: 3}
})
# Out:
#           Name   Age     City   Salary Joining_Date Department       Rating  \
# 0        Alice  25.0   Mumbai  50000.0   2021-01-15         HR         good
# 1          Bob  30.0    Delhi  60000.0   2021-02-15         IT  exceptional
# 2    Charlie    35.0   Mumbai  25000.0   2021-03-03         HR         poor
# 5        David  35.0  Chennai  70000.0   2021-06-01    Finance      average
# 6          Eve  28.0  Chennai  80000.0   2021-07-19         IT         poor
# 7        Frank  20.0     Pune  25000.0   2021-08-25    Finance      average
# 8         None  22.0     Pune  40000.0          NaT         IT         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 5           3
# 6           6
# 7           4
# 8           1

# %%
pd.set_option('future.no_silent_downcasting', True)
df = df.replace(['poor','good','average','exceptional'],[1,2,3,4]).infer_objects(copy=False)

# %%
df
# Out:
#           Name    Age     City   Salary Joining_Date Department  Rating  \
# 0        Alice   25.0   Mumbai  50000.0   2021-01-15         HR     2.0
# 1          Bob   30.0    Delhi  60000.0   2021-02-15         IT     4.0
# 2    Charlie     35.0   Mumbai      NaN   2021-03-03         HR     1.0
# 5        David  999.0  Chennai  70000.0   2021-06-01    Finance     3.0
# 6          Eve   28.0     None  80000.0   2021-07-19         IT     1.0
# 7        Frank   20.0     Pune      NaN   2021-08-25    Finance     NaN
# 8         None   22.0     Pune  40000.0          NaT       None     2.0
#
#    Experience
# 0           2
# 1           5
# 2           8
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df['Joining_Date'] = df['Joining_Date'].fillna(df['Joining_Date'].mode()[0])

# %%
df
# Out:
#           Name    Age     City   Salary Joining_Date Department  Rating  \
# 0        Alice   25.0   Mumbai  50000.0   2021-01-15         HR     2.0
# 1          Bob   30.0    Delhi  60000.0   2021-02-15         IT     4.0
# 2    Charlie     35.0   Mumbai      NaN   2021-03-03         HR     1.0
# 5        David  999.0  Chennai  70000.0   2021-06-01    Finance     3.0
# 6          Eve   28.0     None  80000.0   2021-07-19         IT     1.0
# 7        Frank   20.0     Pune      NaN   2021-08-25    Finance     NaN
# 8         None   22.0     Pune  40000.0   2021-01-15       None     2.0
#
#    Experience
# 0           2
# 1           5
# 2           8
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df.Rating = df.Rating.fillna(2)

# %%
print(df)
# Out:
#           Name    Age     City   Salary Joining_Date Department  Rating  \
# 0        Alice   25.0   Mumbai  50000.0   2021-01-15         HR     2.0
# 1          Bob   30.0    Delhi  60000.0   2021-02-15         IT     4.0
# 2    Charlie     35.0   Mumbai      NaN   2021-03-03         HR     1.0
# 5        David  999.0  Chennai  70000.0   2021-06-01    Finance     3.0
# 6          Eve   28.0     None  80000.0   2021-07-19         IT     1.0
# 7        Frank   20.0     Pune      NaN   2021-08-25    Finance     2.0
# 8         None   22.0     Pune  40000.0   2021-01-15       None     2.0
#
#    Experience
# 0           2
# 1           5
# 2           8
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df
# Out:
#           Name    Age     City   Salary Joining_Date Department  Rating  \
# 0        Alice   25.0   Mumbai  50000.0   2021-01-15         HR     2.0
# 1          Bob   30.0    Delhi  60000.0   2021-02-15         IT     4.0
# 2    Charlie     35.0   Mumbai      NaN   2021-03-03         HR     1.0
# 5        David  999.0  Chennai  70000.0   2021-06-01    Finance     3.0
# 6          Eve   28.0     None  80000.0   2021-07-19         IT     1.0
# 7        Frank   20.0     Pune      NaN   2021-08-25    Finance     2.0
# 8         None   22.0     Pune  40000.0   2021-01-15       None     2.0
#
#    Experience
# 0           2
# 1           5
# 2           8
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df.Name  = df.Name.str.strip()

# %%
df
# Out:
#       Name    Age     City   Salary Joining_Date Department  Rating  \
# 0    Alice   25.0   Mumbai  50000.0   2021-01-15         HR     2.0
# 1      Bob   30.0    Delhi  60000.0   2021-02-15         IT     4.0
# 2  Charlie   35.0   Mumbai      NaN   2021-03-03         HR     1.0
# 5    David  999.0  Chennai  70000.0   2021-06-01    Finance     3.0
# 6      Eve   28.0     None  80000.0   2021-07-19         IT     1.0
# 7    Frank   20.0     Pune      NaN   2021-08-25    Finance     2.0
# 8     None   22.0     Pune  40000.0   2021-01-15       None     2.0
#
#    Experience
# 0           2
# 1           5
# 2           8
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df['City'] = df['City'].str.strip()

# %%
df
# Out:
#       Name    Age     City   Salary Joining_Date Department  Rating  \
# 0    Alice   25.0   Mumbai  50000.0   2021-01-15         HR     2.0
# 1      Bob   30.0    Delhi  60000.0   2021-02-15         IT     4.0
# 2  Charlie   35.0   Mumbai      NaN   2021-03-03         HR     1.0
# 5    David  999.0  Chennai  70000.0   2021-06-01    Finance     3.0
# 6      Eve   28.0     None  80000.0   2021-07-19         IT     1.0
# 7    Frank   20.0     Pune      NaN   2021-08-25    Finance     2.0
# 8     None   22.0     Pune  40000.0   2021-01-15       None     2.0
#
#    Experience
# 0           2
# 1           5
# 2           8
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
df['Name'] = df['Name'].fillna('Unknown')
df.Name
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 5      David
# 6        Eve
# 7      Frank
# 8    Unknown
# Name: Name, dtype: object

# %%
print(df.dtypes)
# Out:
# Name                    object
# Age                    float64
# City                    object
# Salary                 float64
# Joining_Date    datetime64[ns]
# Department              object
# Rating                 float64
# Experience               int64
# dtype: object

# %%
df[['Age','Salary','Rating']] = df[['Age','Salary','Rating']].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 df[['Age','Salary','Rating']] = df[['Age','Salary','Rating']].astype(int)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
# ...

# %%
df.dtypes
# Out:
# Name                    object
# Age                    float64
# City                    object
# Salary                 float64
# Joining_Date    datetime64[ns]
# Department              object
# Rating                 float64
# Experience               int64
# dtype: object

# %%
df[['Age','Salary','Rating']].max()
# Out:
# Age         999.0
# Salary    80000.0
# Rating        4.0
# dtype: float64

# %%
df
# Out:
#       Name    Age     City   Salary Joining_Date Department  Rating  \
# 0    Alice   25.0   Mumbai  50000.0   2021-01-15         HR     2.0
# 1      Bob   30.0    Delhi  60000.0   2021-02-15         IT     4.0
# 2  Charlie   35.0   Mumbai      NaN   2021-03-03         HR     1.0
# 5    David  999.0  Chennai  70000.0   2021-06-01    Finance     3.0
# 6      Eve   28.0     None  80000.0   2021-07-19         IT     1.0
# 7    Frank   20.0     Pune      NaN   2021-08-25    Finance     2.0
# 8  Unknown   22.0     Pune  40000.0   2021-01-15       None     2.0
#
#    Experience
# 0           2
# 1           5
# 2           8
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
dtype = {'Age':'int8'}

# %%
df.Age.dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# Name                    object
# Age                    float64
# City                    object
# Salary                 float64
# Joining_Date    datetime64[ns]
# Department              object
# Rating                 float64
# Experience               int64
# dtype: object

# %%
df.Age = df.Age.astype('int8')

# %%
df.dtypes
# Out:
# Name                    object
# Age                       int8
# City                    object
# Salary                 float64
# Joining_Date    datetime64[ns]
# Department              object
# Rating                 float64
# Experience               int64
# dtype: object

# %%
df[['Rating','Experience']] = df[['Rating','Experience']].astype("int8")

# %%
df.dtypes
# Out:
# Name                    object
# Age                       int8
# City                    object
# Salary                 float64
# Joining_Date    datetime64[ns]
# Department              object
# Rating                    int8
# Experience                int8
# dtype: object

# %%
df[['Name','City','Department']] = df[['Name','City','Department']].astype("string")

# %%
df.dtypes
# Out:
# Name            string[python]
# Age                       int8
# City            string[python]
# Salary                 float64
# Joining_Date    datetime64[ns]
# Department      string[python]
# Rating                    int8
# Experience                int8
# dtype: object

# %%
df.Joining_Date = df.Joining_Date.astype("datetime64[ns]")

# %%
print(df)
# Out:
#       Name  Age     City   Salary Joining_Date Department  Rating  Experience
# 0    Alice   25   Mumbai  50000.0   2021-01-15         HR       2           2
# 1      Bob   30    Delhi  60000.0   2021-02-15         IT       4           5
# 2  Charlie   35   Mumbai      NaN   2021-03-03         HR       1           8
# 5    David  -25  Chennai  70000.0   2021-06-01    Finance       3          -3
# 6      Eve   28     <NA>  80000.0   2021-07-19         IT       1           6
# 7    Frank   20     Pune      NaN   2021-08-25    Finance       2           4
# 8  Unknown   22     Pune  40000.0   2021-01-15       <NA>       2           1

# %%
df
# Out:
#       Name  Age     City   Salary Joining_Date Department  Rating  Experience
# 0    Alice   25   Mumbai  50000.0   2021-01-15         HR       2           2
# 1      Bob   30    Delhi  60000.0   2021-02-15         IT       4           5
# 2  Charlie   35   Mumbai      NaN   2021-03-03         HR       1           8
# 5    David  -25  Chennai  70000.0   2021-06-01    Finance       3          -3
# 6      Eve   28     <NA>  80000.0   2021-07-19         IT       1           6
# 7    Frank   20     Pune      NaN   2021-08-25    Finance       2           4
# 8  Unknown   22     Pune  40000.0   2021-01-15       <NA>       2           1

# %%
print(repr(df['Name'][0]))   # 'Alice'
print(repr(df['Name'][2]))   # 'Charlie'
# Out:
# 'Alice'
# 'Charlie'

# %%
data = {
    'Name': ['Alice', 'bob', '  Charlie  ', 'alice', 'BOB', 'David', 'Eve', 'Frank', None],
    'Age': [25, 30, 35, 25, 30, 999, 28, None, 22],
    'City': ['Mumbai', 'delhi', 'MUMBAI', 'Mumbai', 'Delhi', 'Chennai', None, 'Pune', 'pune'],
    'Salary': [50000, 60000, None, 50000, 60000, 70000, 80000, None, 40000],
    'Joining_Date': ['2021-01-15', '15/02/2021', 'March 3 2021', '2021-01-15', '15/02/2021', '2021-06-01', '2021-07-19', '2021-08-25', None],
    'Department': ['HR', 'IT', 'hr', 'HR', 'it', 'Finance', 'IT', 'Finance', None],
    'Rating': ['good', 'exceptional', 'poor', 'good', 'exceptional', 'average', 'poor', None, 'good'],
    'Experience': [2, 5, 8, 2, 5, -3, 6, 4, 1]
}

cf = pd.DataFrame(data)
print(cf)
# Out:
#           Name    Age     City   Salary  Joining_Date Department       Rating  \
# 0        Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 1          bob   30.0    delhi  60000.0    15/02/2021         IT  exceptional
# 2    Charlie     35.0   MUMBAI      NaN  March 3 2021         hr         poor
# 3        alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 4          BOB   30.0    Delhi  60000.0    15/02/2021         it  exceptional
# 5        David  999.0  Chennai  70000.0    2021-06-01    Finance      average
# 6          Eve   28.0     None  80000.0    2021-07-19         IT         poor
# 7        Frank    NaN     Pune      NaN    2021-08-25    Finance         None
# 8         None   22.0     pune  40000.0          None       None         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
cf
# Out:
#           Name    Age     City   Salary  Joining_Date Department       Rating  \
# 0        Alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 1          bob   30.0    delhi  60000.0    15/02/2021         IT  exceptional
# 2    Charlie     35.0   MUMBAI      NaN  March 3 2021         hr         poor
# 3        alice   25.0   Mumbai  50000.0    2021-01-15         HR         good
# 4          BOB   30.0    Delhi  60000.0    15/02/2021         it  exceptional
# 5        David  999.0  Chennai  70000.0    2021-06-01    Finance      average
# 6          Eve   28.0     None  80000.0    2021-07-19         IT         poor
# 7        Frank    NaN     Pune      NaN    2021-08-25    Finance         None
# 8         None   22.0     pune  40000.0          None       None         good
#
#    Experience
# 0           2
# 1           5
# 2           8
# 3           2
# 4           5
# 5          -3
# 6           6
# 7           4
# 8           1

# %%
print(repr(cf['Name'][0]))   # 'Alice'
print(repr(cf['Name'][2]))   # 'Charlie'
# Out:
# 'Alice'
# '  Charlie  '
